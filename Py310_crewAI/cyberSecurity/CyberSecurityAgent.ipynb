# %% [markdown]
# ##  Cyber Security AI agent

# %%
## !pip install paramiko

# %%
import paramiko

print(   paramiko.__version__   )
# Out:
# 5.0.0

# %%
import os
from crewai_tools import SerperDevTool, BrowserbaseLoadTool, EXASearchTool
from crewai import Agent
from crewai import Task
from crewai import LLM

from langchain_community.llms import Ollama


from crewai import Crew, Process

from crewai_tools import WebsiteSearchTool

# %%
'''

os.environ["OPENAI_API_KEY"] = "your-openai-api-key"
os.environ["OPENAI_API_BASE"] = "https://api.openai.com/v1"

'''



'''
openai_llm = LLM(
    model="gpt-4",
    api_key="your-openai-api-key",
    api_base="https://api.openai.com/v1"
)
'''
# Out:
# '\nopenai_llm = LLM(\n    model="gpt-4",\n    api_key="your-openai-api-key",\n    api_base="https://api.openai.com/v1"\n)\n'

# %%
researcher_agent = Agent(
    role='Cyber Security Analyst',
    goal='Analyze and test cyber security in your corporation',
    backstory="""You're a cyber security specialist at a large company.
    You're responsible for analyzing security data and testing the company cyber security.""",
    verbose=False,
    ## llm=llm_llama
    llm=LLM( model="ollama/llama3.2", base_url="http://localhost:11434" )
)

# %%
task_description      = "What is the linux command to ping 8.8.8.8"
task_expected_output  = "analysis or procedural steps for cyber security"

research_task = Task(
    description=task_description,
    expected_output=task_expected_output,
    agent=researcher_agent,
    ## tools=[ WebsiteSearchTool() ],
    async_execution=True
)

# %%
my_crew = Crew(
    agents=[researcher_agent],
    tasks=[research_task],
    process=Process.sequential,
    verbose=True
)

# %%
result = my_crew.kickoff()
print(result)
# Out:
# # Agent: Cyber Security Analyst
# ## Task: What is the linux command to ping 8.8.8.8
#
#
# # Agent: Cyber Security Analyst
# ## Final Answer:
# To ping 8.8.8.8 using Linux, follow these procedural steps:
#
# 1. Open a terminal window: You can do this by pressing `Ctrl+Alt+T` simultaneously or by searching for "Terminal" in the application menu and opening it.
# 2. Type the command: The syntax to ping 8.8.8.8 is simply: `ping 8.8.8.8`
# 3. Press Enter: This will execute the ping command and display the results.
#
# The `ping` command sends an ICMP echo request to the specified IP address and waits for a response, which can be used to determine if there are any issues with network connectivity between your Linux system and 8.8.8.8.
#
#
# In order to further verify this, it is recommended that you run the ping command multiple times from different terminals or locations within the company's network.
#
# The `ping` command returns a series of lines indicating the status of each packet transmitted, including the round-trip time (RTT), packet loss percentage, and jitter. Analyzing these results can help identify potential network issues.
#
# To further enhance your analysis, consider running other network testing commands such as:
# - `traceroute 8.8.8.8` to visually map out the path the packets took from your system to Google's servers
# - `mtr 8.8.8.8` for a similar but more detailed view of network latency and packet loss
#
#
# To ping 8.8.8.8 using Linux, follow these procedural steps:
#
# 1. Open a terminal window: You can do this by pressing `Ctrl+Alt+T` simultaneously or by searching for "Terminal" in the application menu and opening it.
# 2. Type the command: The syntax to ping 8.8.8.8 is simply: `ping 8.8.8.8`
# 3. Press Enter: This will execute the ping command and display the results.
#
# The `ping` command sends an ICMP echo request to the specified IP address and waits for a response, which can be used to determine if there are any issues with network connectivity between your Linux system and 8.8.8.8.
#
#
# In order to further verify this, it is recommended that you run the ping command multiple times from different terminals or locations within the company's network.
#
# The `ping` command returns a series of lines indicating the status of each packet transmitted, including the round-trip time (RTT), packet loss percentage, and jitter. Analyzing these results can help identify potential network issues.
#
# To further enhance your analysis, consider running other network testing commands such as:
# - `traceroute 8.8.8.8` to visually map out the path the packets took from your system to Google's servers
# - `mtr 8.8.8.8` for a similar but more detailed view of network latency and packet loss

# %%
res1 = result.raw


res1= res1.replace("\n", "")

res1
# Out:
# 'To ping 8.8.8.8 using Linux, follow these procedural steps:1. Open a terminal window: You can do this by pressing `Ctrl+Alt+T` simultaneously or by searching for "Terminal" in the application menu and opening it.2. Type the command: The syntax to ping 8.8.8.8 is simply: `ping 8.8.8.8`3. Press Enter: This will execute the ping command and display the results.The `ping` command sends an ICMP echo request to the specified IP address and waits for a response, which can be used to determine if there are any issues with network connectivity between your Linux system and 8.8.8.8.In order to further verify this, it is recommended that you run the ping command multiple times from different terminals or locations within the company\'s network.The `ping` command returns a series of lines indicating the status of each packet transmitted, including the round-trip time (RTT), packet loss percentage, and jitter. Analyzing these results can help identify potential network issues.To further enhance your analysis, consider running other network testing commands such as:- `traceroute 8.8.8.8` to visually map out the path the packets took from your system to Google\'s servers- `mtr 8.8.8.8` for a similar but more detailed view of network latency and packet loss'

# %% [markdown]
# ## SSH

# %%
import paramiko

# %%
VM_IP = "127.0.0.1"   # replace with your VM's IP
my_port = 2222
USERNAME = "seed"
PASSWORD = "dees"

# %%
# This is what your CrewAI agent produced
results = "ping -c 4 8.8.8.8"

## results = "ls -l"

## results = "id"

# %%
ssh = paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())

# %%
ssh.connect(
    VM_IP,
    port=my_port,
    username=USERNAME,
    password=PASSWORD
)

# %%
stdin, stdout, stderr = ssh.exec_command(results)

# %%
print("COMMAND:")
print(results)

print("\nOUTPUT:")
print(stdout.read().decode())

print("ERRORS:")
print(stderr.read().decode())

ssh.close()
# Out:
# COMMAND:
# ping -c 4 8.8.8.8
#
# OUTPUT:
# PING 8.8.8.8 (8.8.8.8) 56(84) bytes of data.
# 64 bytes from 8.8.8.8: icmp_seq=1 ttl=115 time=19.7 ms
# 64 bytes from 8.8.8.8: icmp_seq=2 ttl=115 time=19.8 ms
# 64 bytes from 8.8.8.8: icmp_seq=3 ttl=115 time=20.9 ms
# 64 bytes from 8.8.8.8: icmp_seq=4 ttl=115 time=20.1 ms
#
# --- 8.8.8.8 ping statistics ---
# 4 packets transmitted, 4 received, 0% packet loss, time 3006ms
# rtt min/avg/max/mdev = 19.654/20.126/20.912/0.486 ms
#
# ERRORS:

# %%
import paramiko
import re

# ============================================================
# VM SETTINGS
# ============================================================

VM_IP = "127.0.0.1"       # CHANGE
VM_PORT = 2222                # CHANGE
USERNAME = "seed"    # CHANGE
PASSWORD = "dees"    # CHANGE

# %%
# ============================================================
# CONNECT TO UBUNTU VM
# ============================================================

ssh = paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())

ssh.connect(
    VM_IP,
    port=VM_PORT,
    username=USERNAME,
    password=PASSWORD
)

print("Connected to VM.")
# Out:
# Connected to VM.

# %%
# ============================================================
# 1. EXECUTE A COMMAND GENERATED BY THE LLM
# ============================================================

# Replace this with your CrewAI result
results = "ping -c 4 8.8.8.8"

# Clean up LLM output
command = results.replace("\n", " ").strip()

print("\nCOMMAND:")
print(command)

stdin, stdout, stderr = ssh.exec_command(command)

output = stdout.read().decode()
error = stderr.read().decode()

print("\nOUTPUT:")
print(output)

if error:
    print("\nERROR:")
    print(error)
# Out:
# COMMAND:
# ping -c 4 8.8.8.8
#
# OUTPUT:
# PING 8.8.8.8 (8.8.8.8) 56(84) bytes of data.
# 64 bytes from 8.8.8.8: icmp_seq=1 ttl=115 time=19.6 ms
# 64 bytes from 8.8.8.8: icmp_seq=2 ttl=115 time=20.7 ms
# 64 bytes from 8.8.8.8: icmp_seq=3 ttl=115 time=21.8 ms
# 64 bytes from 8.8.8.8: icmp_seq=4 ttl=115 time=29.8 ms
#
# --- 8.8.8.8 ping statistics ---
# 4 packets transmitted, 4 received, 0% packet loss, time 3005ms
# rtt min/avg/max/mdev = 19.619/22.994/29.836/4.027 ms

# %% [markdown]
# ##  READ AUTHENTICATION LOG

# %%
# Ubuntu versions differ:
# /var/log/auth.log is common when rsyslog is being used.
# journalctl works on systemd systems.

log_command = "journalctl -u ssh --no-pager -n 50"

stdin, stdout, stderr = ssh.exec_command(log_command)

log_data = stdout.read().decode()
log_error = stderr.read().decode()

print("\n================ AUTH LOG ================\n")
print(log_data)

if log_error:
    print(log_error)
# Out:
# ================ AUTH LOG ================
#
# -- Logs begin at Thu 2023-01-12 15:25:01 EST, end at Sun 2026-09-13 20:11:50 EDT. --
# Sep 03 17:09:21 VM sshd[760]: Server listening on 0.0.0.0 port 22.
# Sep 03 17:09:21 VM sshd[760]: Server listening on :: port 22.
# Sep 03 17:09:21 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 03 19:11:26 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 03 19:11:27 VM systemd[1]: ssh.service: Succeeded.
# Sep 03 19:11:27 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 10 14:47:36 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 10 14:47:36 VM sshd[795]: Server listening on 0.0.0.0 port 22.
# Sep 10 14:47:36 VM sshd[795]: Server listening on :: port 22.
# Sep 10 14:47:36 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 10 16:14:31 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 10 16:14:31 VM systemd[1]: ssh.service: Succeeded.
# Sep 10 16:14:31 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 10 17:03:01 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 10 17:03:02 VM sshd[762]: Server listening on 0.0.0.0 port 22.
# Sep 10 17:03:02 VM sshd[762]: Server listening on :: port 22.
# Sep 10 17:03:02 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 10 18:35:22 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 10 18:35:22 VM systemd[1]: ssh.service: Succeeded.
# Sep 10 18:35:22 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 10 21:05:04 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 10 21:05:06 VM sshd[774]: Server listening on 0.0.0.0 port 22.
# Sep 10 21:05:06 VM sshd[774]: Server listening on :: port 22.
# Sep 10 21:05:06 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 10 22:16:49 VM sshd[774]: Received signal 15; terminating.
# Sep 10 22:16:49 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 10 22:16:49 VM systemd[1]: ssh.service: Succeeded.
# Sep 10 22:16:49 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 13 19:11:15 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 13 19:11:15 VM sshd[797]: Server listening on 0.0.0.0 port 22.
# Sep 13 19:11:15 VM sshd[797]: Server listening on :: port 22.
# Sep 13 19:11:15 VM systemd[1]: Started OpenBSD Secure Shell server.
# -- Reboot --
# Sep 13 19:42:00 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 13 19:42:00 VM sshd[761]: Server listening on 0.0.0.0 port 22.
# Sep 13 19:42:00 VM sshd[761]: Server listening on :: port 22.
# Sep 13 19:42:00 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 13 19:42:54 VM sshd[3163]: Accepted password for seed from 10.0.2.2 port 65067 ssh2
# Sep 13 19:42:54 VM sshd[3163]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# Sep 13 19:44:22 VM sshd[3321]: Accepted password for seed from 10.0.2.2 port 65070 ssh2
# Sep 13 19:44:22 VM sshd[3321]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# Sep 13 19:45:08 VM sshd[3437]: Accepted password for seed from 10.0.2.2 port 65071 ssh2
# Sep 13 19:45:08 VM sshd[3437]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# Sep 13 19:45:33 VM sshd[3520]: Accepted password for seed from 10.0.2.2 port 65072 ssh2
# Sep 13 19:45:33 VM sshd[3520]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# -- Reboot --
# Sep 13 20:10:17 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 13 20:10:18 VM sshd[759]: Server listening on 0.0.0.0 port 22.
# Sep 13 20:10:18 VM sshd[759]: Server listening on :: port 22.
# Sep 13 20:10:18 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 13 20:10:58 VM sshd[3136]: Accepted password for seed from 10.0.2.2 port 62862 ssh2
# Sep 13 20:10:58 VM sshd[3136]: pam_unix(sshd:session): session opened for user seed by (uid=0)

# %% [markdown]
# ## LLM log analysis

# %%
prompt = f"""
You are a cybersecurity analyst.

Analyze the following SSH authentication log.

Identify:
1. Failed login attempts
2. Successful logins
3. Suspicious IP addresses
4. Anything that might indicate an attack

LOG:

{log_data}
"""

print("\n================ PROMPT FOR LLM ================\n")
print(prompt)
# Out:
# ================ PROMPT FOR LLM ================
#
#
# You are a cybersecurity analyst.
#
# Analyze the following SSH authentication log.
#
# Identify:
# 1. Failed login attempts
# 2. Successful logins
# 3. Suspicious IP addresses
# 4. Anything that might indicate an attack
#
# LOG:
#
# -- Logs begin at Thu 2023-01-12 15:25:01 EST, end at Sun 2026-09-13 20:11:50 EDT. --
# Sep 03 17:09:21 VM sshd[760]: Server listening on 0.0.0.0 port 22.
# Sep 03 17:09:21 VM sshd[760]: Server listening on :: port 22.
# Sep 03 17:09:21 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 03 19:11:26 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 03 19:11:27 VM systemd[1]: ssh.service: Succeeded.
# Sep 03 19:11:27 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 10 14:47:36 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 10 14:47:36 VM sshd[795]: Server listening on 0.0.0.0 port 22.
# Sep 10 14:47:36 VM sshd[795]: Server listening on :: port 22.
# Sep 10 14:47:36 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 10 16:14:31 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 10 16:14:31 VM systemd[1]: ssh.service: Succeeded.
# Sep 10 16:14:31 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 10 17:03:01 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 10 17:03:02 VM sshd[762]: Server listening on 0.0.0.0 port 22.
# Sep 10 17:03:02 VM sshd[762]: Server listening on :: port 22.
# Sep 10 17:03:02 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 10 18:35:22 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 10 18:35:22 VM systemd[1]: ssh.service: Succeeded.
# Sep 10 18:35:22 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 10 21:05:04 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 10 21:05:06 VM sshd[774]: Server listening on 0.0.0.0 port 22.
# Sep 10 21:05:06 VM sshd[774]: Server listening on :: port 22.
# Sep 10 21:05:06 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 10 22:16:49 VM sshd[774]: Received signal 15; terminating.
# Sep 10 22:16:49 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 10 22:16:49 VM systemd[1]: ssh.service: Succeeded.
# Sep 10 22:16:49 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 13 19:11:15 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 13 19:11:15 VM sshd[797]: Server listening on 0.0.0.0 port 22.
# Sep 13 19:11:15 VM sshd[797]: Server listening on :: port 22.
# Sep 13 19:11:15 VM systemd[1]: Started OpenBSD Secure Shell server.
# -- Reboot --
# Sep 13 19:42:00 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 13 19:42:00 VM sshd[761]: Server listening on 0.0.0.0 port 22.
# Sep 13 19:42:00 VM sshd[761]: Server listening on :: port 22.
# Sep 13 19:42:00 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 13 19:42:54 VM sshd[3163]: Accepted password for seed from 10.0.2.2 port 65067 ssh2
# Sep 13 19:42:54 VM sshd[3163]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# Sep 13 19:44:22 VM sshd[3321]: Accepted password for seed from 10.0.2.2 port 65070 ssh2
# Sep 13 19:44:22 VM sshd[3321]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# Sep 13 19:45:08 VM sshd[3437]: Accepted password for seed from 10.0.2.2 port 65071 ssh2
# Sep 13 19:45:08 VM sshd[3437]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# Sep 13 19:45:33 VM sshd[3520]: Accepted password for seed from 10.0.2.2 port 65072 ssh2
# Sep 13 19:45:33 VM sshd[3520]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# -- Reboot --
# Sep 13 20:10:17 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 13 20:10:18 VM sshd[759]: Server listening on 0.0.0.0 port 22.
# Sep 13 20:10:18 VM sshd[759]: Server listening on :: port 22.
# Sep 13 20:10:18 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 13 20:10:58 VM sshd[3136]: Accepted password for seed from 10.0.2.2 port 62862 ssh2
# Sep 13 20:10:58 VM sshd[3136]: pam_unix(sshd:session): session opened for user seed by (uid=0)

# %%
# Example:
#
# analysis = your_crewai_function(prompt)
# print(analysis)

# %%
## task_description      = "What is the linux command to ping 8.8.8.8"

task_description = prompt

task_expected_output  = "analysis or procedural steps for cyber security"

research_task = Task(
    description=task_description,
    expected_output=task_expected_output,
    agent=researcher_agent,
    ## tools=[ WebsiteSearchTool() ],
    async_execution=True
)

# %%
my_crew = Crew(
    agents=[researcher_agent],
    tasks=[research_task],
    process=Process.sequential,
    verbose=True
)
# Out:
# 2026-09-13 19:18:49,376 - 4396 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed

# %%
result = my_crew.kickoff()
print(result)
# Out:
# # Agent: Cyber Security Analyst
# ## Task:
# You are a cybersecurity analyst.
#
# Analyze the following SSH authentication log.
#
# Identify:
# 1. Failed login attempts
# 2. Successful logins
# 3. Suspicious IP addresses
# 4. Anything that might indicate an attack
#
# LOG:
#
# -- Logs begin at Thu 2023-01-12 15:25:01 EST, end at Sun 2026-09-13 20:11:50 EDT. --
# Sep 03 17:09:21 VM sshd[760]: Server listening on 0.0.0.0 port 22.
# Sep 03 17:09:21 VM sshd[760]: Server listening on :: port 22.
# Sep 03 17:09:21 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 03 19:11:26 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 03 19:11:27 VM systemd[1]: ssh.service: Succeeded.
# Sep 03 19:11:27 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 10 14:47:36 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 10 14:47:36 VM sshd[795]: Server listening on 0.0.0.0 port 22.
# Sep 10 14:47:36 VM sshd[795]: Server listening on :: port 22.
# Sep 10 14:47:36 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 10 16:14:31 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 10 16:14:31 VM systemd[1]: ssh.service: Succeeded.
# Sep 10 16:14:31 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 10 17:03:01 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 10 17:03:02 VM sshd[762]: Server listening on 0.0.0.0 port 22.
# Sep 10 17:03:02 VM sshd[762]: Server listening on :: port 22.
# Sep 10 17:03:02 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 10 18:35:22 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 10 18:35:22 VM systemd[1]: ssh.service: Succeeded.
# Sep 10 18:35:22 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 10 21:05:04 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 10 21:05:06 VM sshd[774]: Server listening on 0.0.0.0 port 22.
# Sep 10 21:05:06 VM sshd[774]: Server listening on :: port 22.
# Sep 10 21:05:06 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 10 22:16:49 VM sshd[774]: Received signal 15; terminating.
# Sep 10 22:16:49 VM systemd[1]: Stopping OpenBSD Secure Shell server...
# Sep 10 22:16:49 VM systemd[1]: ssh.service: Succeeded.
# Sep 10 22:16:49 VM systemd[1]: Stopped OpenBSD Secure Shell server.
# -- Reboot --
# Sep 13 19:11:15 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 13 19:11:15 VM sshd[797]: Server listening on 0.0.0.0 port 22.
# Sep 13 19:11:15 VM sshd[797]: Server listening on :: port 22.
# Sep 13 19:11:15 VM systemd[1]: Started OpenBSD Secure Shell server.
# -- Reboot --
# Sep 13 19:42:00 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 13 19:42:00 VM sshd[761]: Server listening on 0.0.0.0 port 22.
# Sep 13 19:42:00 VM sshd[761]: Server listening on :: port 22.
# Sep 13 19:42:00 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 13 19:42:54 VM sshd[3163]: Accepted password for seed from 10.0.2.2 port 65067 ssh2
# Sep 13 19:42:54 VM sshd[3163]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# Sep 13 19:44:22 VM sshd[3321]: Accepted password for seed from 10.0.2.2 port 65070 ssh2
# Sep 13 19:44:22 VM sshd[3321]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# Sep 13 19:45:08 VM sshd[3437]: Accepted password for seed from 10.0.2.2 port 65071 ssh2
# Sep 13 19:45:08 VM sshd[3437]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# Sep 13 19:45:33 VM sshd[3520]: Accepted password for seed from 10.0.2.2 port 65072 ssh2
# Sep 13 19:45:33 VM sshd[3520]: pam_unix(sshd:session): session opened for user seed by (uid=0)
# -- Reboot --
# Sep 13 20:10:17 VM systemd[1]: Starting OpenBSD Secure Shell server...
# Sep 13 20:10:18 VM sshd[759]: Server listening on 0.0.0.0 port 22.
# Sep 13 20:10:18 VM sshd[759]: Server listening on :: port 22.
# Sep 13 20:10:18 VM systemd[1]: Started OpenBSD Secure Shell server.
# Sep 13 20:10:58 VM sshd[3136]: Accepted password for seed from 10.0.2.2 port 62862 ssh2
# Sep 13 20:10:58 VM sshd[3136]: pam_unix(sshd:session): session opened for user seed by (uid=0)
#
#
#
#
# # Agent: Cyber Security Analyst
# ## Final Answer:
# 1. Failed login attempts:
# There are no specific failed login attempts mentioned in the provided SSH authentication log. However, we can infer that there were some successful logins from IP addresses 10.0.2.2 with multiple connections (65067-65072) and another connection (62862).
#
# 2. Successful logins:
# Successful logins are listed as follows:
#    - Sep 13 19:42:54 VM sshd[3163]: Accepted password for seed from 10.0.2.2 port 65067 ssh2
#    - Sep 13 19:44:22 VM sshd[3321]: Accepted password for seed from 10.0.2.2 port 65070 ssh2
#    - Sep 13 19:45:08 VM sshd[3437]: Accepted password for seed from 10.0.2.2 port 65071 ssh2
#    - Sep 13 19:45:33 VM sshd[3520]: Accepted password for seed from 10.0.2.2 port 65072 ssh2
#    - Sep 13 20:10:58 VM sshd[3136]: Accepted password for seed from 10.0.2.2 port 62862 ssh2
#
# 3. Suspicious IP addresses:
# Based on the provided log, there is only one suspicious IP address mentioned which is not an internal IP but rather a remote IP address from 10.0.2.2. This could be a possible sign of an attack or unauthorized access.
#
# 4. Anything that might indicate an attack:
# The presence of multiple successful connections from a single IP address (10.0.2.2) using different ports and the timing of these events suggest a potential brute-force attack on the system.
#
#
# 1. Failed login attempts:
# There are no specific failed login attempts mentioned in the provided SSH authentication log. However, we can infer that there were some successful logins from IP addresses 10.0.2.2 with multiple connections (65067-65072) and another connection (62862).
#
# 2. Successful logins:
# Successful logins are listed as follows:
#    - Sep 13 19:42:54 VM sshd[3163]: Accepted password for seed from 10.0.2.2 port 65067 ssh2
#    - Sep 13 19:44:22 VM sshd[3321]: Accepted password for seed from 10.0.2.2 port 65070 ssh2
#    - Sep 13 19:45:08 VM sshd[3437]: Accepted password for seed from 10.0.2.2 port 65071 ssh2
#    - Sep 13 19:45:33 VM sshd[3520]: Accepted password for seed from 10.0.2.2 port 65072 ssh2
#    - Sep 13 20:10:58 VM sshd[3136]: Accepted password for seed from 10.0.2.2 port 62862 ssh2
#
# 3. Suspicious IP addresses:
# Based on the provided log, there is only one suspicious IP address mentioned which is not an internal IP but rather a remote IP address from 10.0.2.2. This could be a possible sign of an attack or unauthorized access.
#
# 4. Anything that might indicate an attack:
# The presence of multiple successful connections from a single IP address (10.0.2.2) using different ports and the timing of these events suggest a potential brute-force attack on the system.

# %%
res1 = result.raw


res1= res1.replace("\n", "")

res1
# Out:
# '1. Failed login attempts: There are no specific failed login attempts mentioned in the provided SSH authentication log. However, we can infer that there were some successful logins from IP addresses 10.0.2.2 with multiple connections (65067-65072) and another connection (62862).2. Successful logins:Successful logins are listed as follows:   - Sep 13 19:42:54 VM sshd[3163]: Accepted password for seed from 10.0.2.2 port 65067 ssh2   - Sep 13 19:44:22 VM sshd[3321]: Accepted password for seed from 10.0.2.2 port 65070 ssh2   - Sep 13 19:45:08 VM sshd[3437]: Accepted password for seed from 10.0.2.2 port 65071 ssh2   - Sep 13 19:45:33 VM sshd[3520]: Accepted password for seed from 10.0.2.2 port 65072 ssh2   - Sep 13 20:10:58 VM sshd[3136]: Accepted password for seed from 10.0.2.2 port 62862 ssh23. Suspicious IP addresses:Based on the provided log, there is only one suspicious IP address mentioned which is not an internal IP but rather a remote IP address from 10.0.2.2. This could be a possible sign of an attack or unauthorized access.4. Anything that might indicate an attack:The presence of multiple successful connections from a single IP address (10.0.2.2) using different ports and the timing of these events suggest a potential brute-force attack on the system.'

# %% [markdown]
# ## Here we assume an advanced LLM like chatGPT or Claude gen a python script
#
# * this may be more challenging for llama3.2

# %%
generated_python_code = r'''
import subprocess
import re
from collections import Counter

result = subprocess.run(
    ["journalctl", "-u", "ssh", "--no-pager", "-n", "200"],
    capture_output=True,
    text=True
)

log = result.stdout

ips = re.findall(
    r"Failed password.*from ([0-9]+\.[0-9]+\.[0-9]+\.[0-9]+)",
    log
)

counts = Counter(ips)

print("FAILED SSH LOGIN REPORT")
print("-----------------------")

if not counts:
    print("No failed SSH logins found. Claude AI")

for ip, count in counts.most_common():
    print(f"{ip}: {count} failed attempts. Claude AI")

    if count >= 3:
        print(f"  WARNING: {ip} may be suspicious. Claude AI")
'''

# %% [markdown]
# ## Send python script to VM

# %%
remote_file = "/tmp/analyze_ClaudeAI_ssh.py"

sftp = ssh.open_sftp()

with sftp.file(remote_file, "w") as f:
    f.write(generated_python_code)

sftp.close()

print("\nPython script uploaded to:")
print(remote_file)
# Out:
# Python script uploaded to:
# /tmp/analyze_ClaudeAI_ssh.py

# %% [markdown]
# ## Now we run the python script on the VM

# %%
stdin, stdout, stderr = ssh.exec_command(
    f"python3 {remote_file}"
)

script_output = stdout.read().decode()
script_error = stderr.read().decode()

print("\n================ AGENT SCRIPT RESULT ================\n")
print(script_output)

if script_error:
    print("\nERROR:")
    print(script_error)
# Out:
# ================ AGENT SCRIPT RESULT ================
#
# FAILED SSH LOGIN REPORT
# -----------------------
# No failed SSH logins found. Claude AI

# %% [markdown]
# ## Close SSH connection

# %%
ssh.close()

print("\nSSH connection closed.")
# Out:
# SSH connection closed.
